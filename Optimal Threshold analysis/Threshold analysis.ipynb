# %% [markdown]
# # Optimal Threshold Analysis for Watson Assistant
#
# This notebook can be used to search for the optimal value of the confidence level threshold to use in your Waston Assistant (WA) workspace.
#
# ### What is the 'threshold'?
# The threshold is the minimum level of confidence level that you are expecting in order to check if the input text is triggering the right intent. If the confidence level of the triggered intent is below the threshold, this question will not be answered by the virtual agent. The default value in WA is 20%: if the confidence level is less than 20% the utterance is classified as `irrelevant`. However, based on the use case, this value can be too low. So, what is the optimal threshold?
#
# ### Optimal threshold
# There is no 'one exact answer' because the blind set used in the analysis will represent a major factor. "This blind set should be representative of real customer questions, and include some noise that Watson should ignore by design." For more details check out [this article](https://medium.com/ibm-watson/how-to-set-the-optimal-confidence-threshold-for-your-assistant-bbb1be6f294f).
#
# However, this notebook will allow you to have a first estimation and support your decision based on quantitative analysis which can be then further adjusted through real customer interactions.
#
# <div class="alert alert-block alert-info">
# <b>Notebook Summary</b>
# <br>
#
# 1. <b>Run a blind test</b> : use one of the notebook: `Performance Testing` or `K-fold cross-validation test` and get the results in a CSV format.<br>
# 2. <b>Feed your results</b> : the CSV file should contain "predicted_intent","actual_intent1", "actual_confidence1" columns<br>
# 3. <b>Exploratory analysis</b> : visualise the metrics obtained by the analysis <br>
# 4. <b>Conclusion</b> : based on the exploration of the data, decide what is your optimal threshold <br>
# </div>

# %% [markdown]
# ## Libraries

# %%
import json 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from IPython.display import display, Math, Latex
from sklearn.metrics import *
from sklearn.model_selection import *

# %% [markdown]
# ## 1. Run a blind test
# In order to use this notebook, we need to have a result from a performance testing: a table containing results on how the chatbot is behaving.
# - **Option 1** : If you have available a blind set, you can use the `Perfomance Testing` notebook where you can get the results file in a CSV format.
# - **Option 2** : If you currently do not have any blind test, you can try to feed the results of a K-fold testing. The notebook `K-fold Cross Validation Test` will produce `k` results file in CSV. You can pick one of them and feed the results in this notebook.

# %% [markdown]
# ## 2. Feed your results
#
# <div class="alert alert-block alert-warning">
#
# <b>Data needed from the user</b>
# <br>
#
# 1. <b>thresholds</b> : List of confidence level threshold to test <br>
# 2. <b>results_df</b> : Rename your result file in `results.csv` and put it in the folder "data" in the same directory of this notebook.<br>
# This file must have the following columns:
#     - "predicted_intent"
#     - "actual_intent1"
#     - "actual_confidence1"
# </div>

# %%
thresholds = [0.2,0.3,0.35,0.4,0.45,0.5,0.55,0.60,0.65,0.70,0.75,0.80,0.85,0.90] #USER CHOICE

results_df = pd.read_csv("./data/results.csv", index_col=0)  #USER CHOICE
results_df.head(5)
# Out:
#               original_text              predicted_intent  \
# 0        I am still holding  Bot_Control_Confirm_Presence
# 1               You around?  Bot_Control_Confirm_Presence
# 2  Am I talking to someone?  Bot_Control_Confirm_Presence
# 3     Did you go somewhere?  Bot_Control_Confirm_Presence
# 4        tell me what to do                       mission
#
#                  actual_intent1  actual_confidence1  \
# 0           Bot_Control_Standby            0.586996
# 1             General_Greetings            0.471453
# 2          General_Human_or_Bot            0.465707
# 3  Bot_Control_Confirm_Presence            0.730469
# 4                       mission            0.662601
#
#                  actual_intent2  actual_confidence2  actual_intent3  \
# 0                General_Ending            0.329618        toppings
# 1  Bot_Control_Confirm_Presence            0.291613   General_Jokes
# 2      General_Connect_to_Agent            0.368152  General_Ending
# 3     Bot_Control_Clarification            0.281508      turn-right
# 4                      location            0.345594            help
#
#    actual_confidence3
# 0            0.256429
# 1            0.267842
# 2            0.328591
# 3            0.248598
# 4            0.293543

# %%
def threshold_analysis(df, confidence):
    """
    This function analyse the results obtained by the blind test and will create the metrics 
    for each level of threshold that we want to test. 
    
    Parameter:
        df: it is the dataframe containing the results from the blind test 
        confidence: it is the list of threshold that we want to test 
    
    Return: 
        analysis: dataframe with all the metrics per each threshold
    """
    analysis  = pd.DataFrame(columns = ["threshold", "correct","incorrect","missed","ignored"])

    for i in range(len(confidence)):
        total = len(df)
        correct = len(df.loc[(df["predicted_intent"]==df["actual_intent1"]) & (df["actual_confidence1"]>=confidence[i])])
        incorrect = len(df.loc[(df["predicted_intent"]!=df["actual_intent1"]) & (df["actual_confidence1"]>=confidence[i])])
        missed = len(df.loc[(df["predicted_intent"]==df["actual_intent1"]) & (df["actual_confidence1"]<confidence[i])])
        ignored = len(df.loc[(df["predicted_intent"]!=df["actual_intent1"]) & (df["actual_confidence1"]<confidence[i])])

        analysis = analysis.append({
            "threshold": confidence[i],
            "correct": correct, 
            "incorrect": incorrect,
            "missed": missed, 
            "ignored": ignored, 
            "accuracy": correct/total, 
            "incorrect_rate": incorrect/total,
            "effectiveness": correct / (correct + incorrect),
            "coverage": (correct + incorrect)/total
        }, ignore_index=True)

    analysis = analysis.sort_values('threshold', ascending = 0)
    
    return analysis 


threshold_res = threshold_analysis(results_df, thresholds)
threshold_res
# Out:
#     threshold  correct  incorrect  missed  ignored  accuracy  coverage  \
# 13       0.90     33.0        0.0    40.0     21.0  0.351064  0.351064
# 12       0.85     40.0        1.0    33.0     20.0  0.425532  0.436170
# 11       0.80     49.0        3.0    24.0     18.0  0.521277  0.553191
# 10       0.75     53.0        4.0    20.0     17.0  0.563830  0.606383
# 9        0.70     57.0        4.0    16.0     17.0  0.606383  0.648936
# 8        0.65     63.0        6.0    10.0     15.0  0.670213  0.734043
# 7        0.60     67.0        8.0     6.0     13.0  0.712766  0.797872
# 6        0.55     69.0        9.0     4.0     12.0  0.734043  0.829787
# 5        0.50     72.0       11.0     1.0     10.0  0.765957  0.882979
# 4        0.45     73.0       16.0     0.0      5.0  0.776596  0.946809
# 3        0.40     73.0       17.0     0.0      4.0  0.776596  0.957447
# 2        0.35     73.0       19.0     0.0      2.0  0.776596  0.978723
# 1        0.30     73.0       21.0     0.0      0.0  0.776596  1.000000
# 0        0.20     73.0       21.0     0.0      0.0  0.776596  1.000000
#
#     effectiveness  incorrect_rate
# 13       1.000000        0.000000
# 12       0.975610        0.010638
# 11       0.942308        0.031915
# 10       0.929825        0.042553
# 9        0.934426        0.042553
# 8        0.913043        0.063830
# 7        0.893333        0.085106
# 6        0.884615        0.095745
# 5        0.867470        0.117021
# 4        0.820225        0.170213
# 3        0.811111        0.180851
# 2        0.793478        0.202128
# 1        0.776596        0.223404
# 0        0.776596        0.223404

# %% [markdown]
# ## Metrics Explanation
#
# In this notebook we are following the metrics used in [this article](https://medium.com/ibm-watson/how-to-set-the-optimal-confidence-threshold-for-your-assistant-bbb1be6f294f)
#
#
# The most important division is the following:
# 1. **Correct**: the number of questions that the bot answered correctly, above the threshold
# 2. **Missed**: the number of questions that the bot didn't answer because below the threshold, despite detecting the correct intent. (Missed opportunity!)
# 3. **Incorrect**: the number of question that the bot answered incorrectly, above the threshold.
# 4. **Ignored**: the number of questions that triggered the wrong intent but were never answered because below the threshold.

# %% [markdown]
# <img src="./images/metrics3.png">

# %% [markdown]
# In addition to those, we decided to add also more metrics:
# 1. **Accuracy**: the number of correct answers on the total number of questions
# 2. **Incorrect rate**: the number of incorrect answers on the total number of questions
# 3. **Effectiveness**: the number of correct answers on the total number of questions answered
# 4. **Coverage**: questions answered by the chatbot - number of incorrect + correct questions on the total questions.

# %% [markdown]
# ## 3. Exploratory analysis
#
# ### Approach 1 - Correct and Incorrect rates
# Let's start by visualizing Correct, Incorrect, Missed and Ignored by threshold.

# %%
plt.figure(figsize=(14,8))
plt.plot('threshold', 'correct', data = threshold_res , color='darkturquoise', linewidth=2)
plt.plot('threshold', 'incorrect', data = threshold_res , color='deeppink', linewidth=2)
plt.plot('threshold', 'missed', data = threshold_res, color='darkturquoise',linestyle='dashed', linewidth=2)
plt.plot('threshold', 'ignored', data = threshold_res,color='deeppink',linestyle='dashed', linewidth=2)
plt.legend()

# %% [markdown]
# #### Observation
# Correct and Missed (blue): opposite trend as expected as they are complementary. Higher the threshold, higher the number of missed opportunities. <br>
# Incorrect and Ignored (pink): opposite trend as expected as they are complementary. Higher the threshold, higher the number of ignored questions.
#
# We can see the number of correct answers starts to decline more visibly around the threshold 0.5.
# The number of incorrect answers starts to decline more visibly around the threshold 0.45.

# %% [markdown]
# ### Approach 2 - Coverage and Effectiveness
# Let's plot Accuracy, effectiveness, coverage, incorrect_rate, incorrect_rate_QA, questions_unanswered.

# %%
plt.figure(figsize=(14,8))
plt.plot('threshold', 'effectiveness', data = threshold_res, color='blue', linewidth=2)
plt.plot('threshold', 'coverage', data = threshold_res,color='lightsteelblue', linewidth=2)
plt.plot('threshold', 'accuracy', data = threshold_res , color='cornflowerblue', linestyle='dashed',linewidth=2)
plt.plot('threshold', 'incorrect_rate', data = threshold_res , color='deepskyblue', linestyle='dashed',linewidth=2)

plt.legend()

# %% [markdown]
# #### Observations
# Effectiveness and Coverage: we are searching for a trade-off between these curves. The intersection is around 0.52.
#
# Accuracy and Incorrect_rate are telling the same information that we saw above (correct vs incorrect), the visible decline starts around 0.45.

# %% [markdown]
# ### Approach 3 - Delta calculation

# %% [markdown]
# The idea behind is that when we lower the threshold (starting from 90% in our case,) the number of correct answers increases, but also the number of incorrect one. So we want to stop decreasing the threshold when the number of correct answer that we gain, is less than the number of incorrect answers that occurs.
#
# Below, we created a table that calculates the delta per row.

# %%
analysis_diff = threshold_res.diff()
analysis_diff["threshold"] = threshold_res["threshold"]
analysis_diff
# Out:
#     threshold  correct  incorrect  missed  ignored  accuracy  coverage  \
# 13       0.90      NaN        NaN     NaN      NaN       NaN       NaN
# 12       0.85      7.0        1.0    -7.0     -1.0  0.074468  0.085106
# 11       0.80      9.0        2.0    -9.0     -2.0  0.095745  0.117021
# 10       0.75      4.0        1.0    -4.0     -1.0  0.042553  0.053191
# 9        0.70      4.0        0.0    -4.0      0.0  0.042553  0.042553
# 8        0.65      6.0        2.0    -6.0     -2.0  0.063830  0.085106
# 7        0.60      4.0        2.0    -4.0     -2.0  0.042553  0.063830
# 6        0.55      2.0        1.0    -2.0     -1.0  0.021277  0.031915
# 5        0.50      3.0        2.0    -3.0     -2.0  0.031915  0.053191
# 4        0.45      1.0        5.0    -1.0     -5.0  0.010638  0.063830
# 3        0.40      0.0        1.0     0.0     -1.0  0.000000  0.010638
# 2        0.35      0.0        2.0     0.0     -2.0  0.000000  0.021277
# 1        0.30      0.0        2.0     0.0     -2.0  0.000000  0.021277
# 0        0.20      0.0        0.0     0.0      0.0  0.000000  0.000000
#
#     effectiveness  incorrect_rate
# 13            NaN             NaN
# 12      -0.024390        0.010638
# 11      -0.033302        0.021277
# 10      -0.012483        0.010638
# 9        0.004602        0.000000
# 8       -0.021383        0.021277
# 7       -0.019710        0.021277
# 6       -0.008718        0.010638
# 5       -0.017146        0.021277
# 4       -0.047245        0.053191
# 3       -0.009114        0.010638
# 2       -0.017633        0.021277
# 1       -0.016883        0.021277
# 0        0.000000        0.000000

# %%
plt.figure(figsize=(14,8))
plt.plot('threshold', 'correct', data = analysis_diff , color='darkturquoise', linewidth=2, label = "correct_delta")
plt.plot('threshold', 'incorrect', data = analysis_diff , color='deeppink', linewidth=2, label = "incorrect_delta")
plt.legend()

# %% [markdown]
# #### Observation
#
# From the graph above, you can see that the intersection between the lines are around 0.48.
# If the threshold is higher than 0.48, the delta of correct answers is higher than the delta of incorrect ones.
# If it's lower than 0.48, the delta of incorrect answers is higher than the delta of the corrects answers.

# %% [markdown]
# ### Approach 4 - the 'knee' calculation
# I am going to calculate mathematically where the "accuracy" and "incorrect_rate" starts to drop more rapidly. In order to find the max value of descrease, we can study the slope of the curves. The slope is the steepness of the line. What we want to know is where the steepest slope is. In order words, we need to study how the slopes are changing ("The rate of change of the rate of change" = acceleration). The second derivatives can help us.
#
# Since we have finite points, a good approximation of the second derivatives can be done by using the [finite difference methods](https://en.wikipedia.org/wiki/Finite_difference): we choose to use the Central Difference Derivation method where the second derivatives approximation is the following:
#
# \begin{equation*}
# f''(x) \approx \frac{f(x+h) -2f(x) + f(x-h)}{h^2}
# \end{equation*}
#
# In our case h = 1 ,the denominator is negligible. Let's focus on the numerator.

# %%
threshold4 = threshold_res.copy()
threshold4['accuracy_secDer']= np.NaN
threshold4['incorrect_rate_secDer']= np.NaN

# %%
for i in range(len(threshold_res)):
    if (i != 0 and i != len(threshold_res)-1):
        threshold4['accuracy_secDer'][i] = (threshold4['accuracy'][i+1] + threshold4['accuracy'][i-1] - 2*threshold4['accuracy'][i+1])
        threshold4['incorrect_rate_secDer'][i] = threshold4['incorrect_rate'][i+1] + threshold4['incorrect_rate'][i-1] - 2*threshold4['incorrect_rate'][i+1]
        
    else: 
        threshold4['accuracy_secDer'][i] = np.NaN
        threshold4['incorrect_rate_secDer'][i] = np.NaN


threshold4
# Out:
#     threshold  correct  incorrect  missed  ignored  accuracy  coverage  \
# 13       0.90     33.0        0.0    40.0     21.0  0.351064  0.351064
# 12       0.85     40.0        1.0    33.0     20.0  0.425532  0.436170
# 11       0.80     49.0        3.0    24.0     18.0  0.521277  0.553191
# 10       0.75     53.0        4.0    20.0     17.0  0.563830  0.606383
# 9        0.70     57.0        4.0    16.0     17.0  0.606383  0.648936
# 8        0.65     63.0        6.0    10.0     15.0  0.670213  0.734043
# 7        0.60     67.0        8.0     6.0     13.0  0.712766  0.797872
# 6        0.55     69.0        9.0     4.0     12.0  0.734043  0.829787
# 5        0.50     72.0       11.0     1.0     10.0  0.765957  0.882979
# 4        0.45     73.0       16.0     0.0      5.0  0.776596  0.946809
# 3        0.40     73.0       17.0     0.0      4.0  0.776596  0.957447
# 2        0.35     73.0       19.0     0.0      2.0  0.776596  0.978723
# 1        0.30     73.0       21.0     0.0      0.0  0.776596  1.000000
# 0        0.20     73.0       21.0     0.0      0.0  0.776596  1.000000
#
#     effectiveness  incorrect_rate  accuracy_secDer  incorrect_rate_secDer
# 13       1.000000        0.000000              NaN                    NaN
# 12       0.975610        0.010638         0.170213               0.031915
# 11       0.942308        0.031915         0.138298               0.031915
# 10       0.929825        0.042553         0.085106               0.010638
# 9        0.934426        0.042553         0.106383               0.021277
# 8        0.913043        0.063830         0.106383               0.042553
# 7        0.893333        0.085106         0.063830               0.031915
# 6        0.884615        0.095745         0.053191               0.031915
# 5        0.867470        0.117021         0.042553               0.074468
# 4        0.820225        0.170213         0.010638               0.063830
# 3        0.811111        0.180851         0.000000               0.031915
# 2        0.793478        0.202128         0.000000               0.042553
# 1        0.776596        0.223404         0.000000               0.021277
# 0        0.776596        0.223404              NaN                    NaN

# %% [markdown]
# Since we want to have an optimal threshold that does not go beyond 0.8 since it would be too high for any use case, we are going to manually restrict the search range (threshold from 0.2 to 0.8 excluded).

# %%
threshold_res_filtered = threshold4.loc[threshold_res['threshold']<0.8]
threshold_res_filtered = threshold_res_filtered.sort_values('threshold', ascending = 1)

# %%
plt.figure(figsize=(14,8))
plt.plot('threshold', 'accuracy_secDer', data = threshold4 , color='darkturquoise', linewidth=2, label = "Second Derivatived of Accuracy")
plt.plot('threshold', 'incorrect_rate_secDer', data = threshold4 , color='deeppink', linewidth=2, label = "Second Derivatived of Incorrect_rate")
plt.axvline(x = threshold_res_filtered['threshold'][threshold_res_filtered['incorrect_rate_secDer'].idxmax()], color = 'lightpink', linestyle='dashed')
plt.axvline(x = threshold_res_filtered['threshold'][threshold_res_filtered['accuracy_secDer'].idxmax()], color = 'paleturquoise', linestyle='dashed')
plt.show()

# %% [markdown]
# #### Observation
# This graph is showing you the second derivatives and the vertical lines are identifying the max value of the second derivatives for Incorrect_rate (pink) and Accuracy (blue).
#
# Max second derivatives of Incorrect_rate = is the point where the incorrect_rate start to decline more rapidly compared to the rest of the distribution.
#
# Max second derivatives of Accuracy = is the point where the accuracy rate starts to decline more rapidly compared to the rest of the distribution.
#
# Therefore, what we want to have is a threshold that is higher than the pink vertical line and lower than the blue line.

# %% [markdown]
# ### Approach 5 - the heuristic reputation equation

# %% [markdown]
# For each use case, we might have different preferences: we might prefer the bot to respond rather than not responding, or you might prefer a wrong answer to a non-answered questions. Based on Anna Chaney suggestion, let's maximise the Reputation equation.
#
# \begin{equation*}
# Reputation = \frac{\alpha*correct - \beta*incorrect - \gamma*unanswered}{TotalQuestions}
# \end{equation*}
#
# where unanswered = missed + ignored
#
# An Example of starting values for the parameters:
#
# \begin{equation*}
# \alpha, \beta, \gamma = [10,10,1]
# \end{equation*}
#
# which means it is 10 times better to not answer a question than answering something wrong and it is 10 times better to answer correctly than not answer anything. These values can be changed based on the use case.

# %%
threshold5 = threshold_res.copy()

alpha = 10
beta = 10 
gamma = 1

threshold5['reputation'] = (alpha*threshold5['correct']- \
                            gamma*(threshold5['missed']+threshold5['ignored'])-\
                            beta*(threshold5['incorrect']))/(threshold5['correct']+\
                                                            threshold5['incorrect']+\
                                                            threshold5['missed']+\
                                                            threshold5['ignored'])

# %% [markdown]
# Let's plot the varaibles in the same plot (most likely different y-scales)

# %%
fig, ax1 = plt.subplots(figsize=(14,8))
color1 = 'goldenrod'
ax1.set_xlabel('threshold')
ax1.set_ylabel('Reputation', color=color1)
ax1.plot('threshold', 'reputation', data = threshold5, color='gold')
ax1.tick_params(axis='y', labelcolor=color1)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color2 = 'blue'
ax2.set_ylabel('Effectiveness', color=color2)  # we already handled the x-label with ax1
ax2.plot('threshold', 'effectiveness', data = threshold5, color=color2)
ax2.tick_params(axis='y', labelcolor=color2)

plt.axvline(x = threshold5['threshold'][threshold5['reputation'].idxmax()], color = 'gold', linestyle='dashed')

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# #### Observation
# We want to get the maximum value of the Reputation function and the peak reputation is at 0.5 confidence level threshold where we are expecting to get 87% of effectiveness (Precision).

# %% [markdown]
# ## 4. Conclusions
#
# ### Approach 1: Correct vs Incorrect
# we have started to see visually that there is a slightly "knee effect" starting from 0.5 : where the number of Correct answers starts to decline.
#
# ### Approach 2: Effectiveness vs Coverage
# From approach 2, we saw the relationship between Coverage and Effectiveness. We want to have high levels of coverage (number of questions answered) and high level of effectiveness (high number of correct answers aka precision). The intersection shows that 0.5 is again a good trade-off point between the trends.
#
# ### Approach 3: Delta Calculation
# From approach 3, we calculated the delta of the metrics. This will allow to see when the delta of the number of incorrect answers is higher than the delta of the correct ones. It is again confirmed that 0.5 can be a good approximation of the confidence level threshold.
#
# ### Approach 4: the 'knee' calculation
# a mathematical way to find the 'knee' of the accuracy and incorrect_rate functions. the optimal range should go from 0.5-0.7.
#
# ### Approach 5: Reputation equation
# Based on the use case, you can customise the calculation of the reputation equation and it scope is to maximise the function. The max value corresponds to 0.5 confidence level threshold.
#
# All the approaches are suggesting to choose a threshold that is close to 0.5.

# %% [markdown]
# ## Author:
# - **[Erika Agostinelli](https://www.linkedin.com/in/erikaagostinelli/)** is a Data Scientist and AI specialist part of IBM Data Science Elite Team where she specializes in Analytics platforms and Machine Learning solutions.

# %% [markdown]
# Copyright 2019 IBM Corp. All Rights Reserved.
